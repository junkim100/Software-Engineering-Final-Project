# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv("./test.csv")
type(df)
df
# Out:
#     Body   Acidity   Flavor   Aroma     Roast   Roastery   RoastDate  \
# 0  body1  acidity5  flavor2  aroma3     light  roastery1  2023-02-01
# 1  body2  acidity4  flavor2  aroma2     light  roastery3  2023-01-25
# 2  body1  acidity1  flavor2  aroma1     light  roastery2  2023-02-09
# 3  body4  acidity2  flavor3  aroma2    medium  roastery1  2023-02-04
# 4  body3  acidity5  flavor4  aroma1    medium  roastery5  2023-02-07
# 5  body1  acidity3  flavor1  aroma1    medium  roastery5  2023-01-24
# 6  body5  acidity1  flavor5  aroma4    medium  roastery3  2023-01-23
# 7  body2  acidity4  flavor3  aroma4      dark  roastery3  2023-02-02
# 8  body3  acidity2  flavor4  aroma5      dark  roastery2  2023-02-03
# 9  body2  acidity1  flavor5  aroma4  espresso  roastery3  2023-02-07
#
#     Country   Blend  Sold
# 0  Columbia  blend1     0
# 1  Ethiopia  blend3     0
# 2    Brazil  blend2     0
# 3  Columbia  blend3     0
# 4  Honduras  blend2     0
# 5  Honduras  blend1     0
# 6   Vietnam  blend5     0
# 7  Columbia  blend5     0
# 8    Brazil  blend4     0
# 9    Brazil  blend4     0

# %%
df.loc[len(df.index)] = ["body6", "acidity6", "flavor6", "aroma6", "unroasted", "roastery6", "2023-02-09", "Columbia", "blend6", 0]

# %%
df
# Out:
#      Body   Acidity   Flavor   Aroma      Roast   Roastery   RoastDate  \
# 0   body1  acidity5  flavor2  aroma3      light  roastery1  2023-02-01
# 1   body2  acidity4  flavor2  aroma2      light  roastery3  2023-01-25
# 2   body1  acidity1  flavor2  aroma1      light  roastery2  2023-02-09
# 3   body4  acidity2  flavor3  aroma2     medium  roastery1  2023-02-04
# 4   body3  acidity5  flavor4  aroma1     medium  roastery5  2023-02-07
# 5   body1  acidity3  flavor1  aroma1     medium  roastery5  2023-01-24
# 6   body5  acidity1  flavor5  aroma4     medium  roastery3  2023-01-23
# 7   body2  acidity4  flavor3  aroma4       dark  roastery3  2023-02-02
# 8   body3  acidity2  flavor4  aroma5       dark  roastery2  2023-02-03
# 9   body2  acidity1  flavor5  aroma4   espresso  roastery3  2023-02-07
# 10  body6  acidity6  flavor6  aroma6  unroasted  roastery6  2023-02-09
#
#      Country   Blend  Sold
# 0   Columbia  blend1     0
# 1   Ethiopia  blend3     0
# 2     Brazil  blend2     0
# 3   Columbia  blend3     0
# 4   Honduras  blend2     0
# 5   Honduras  blend1     0
# 6    Vietnam  blend5     0
# 7   Columbia  blend5     0
# 8     Brazil  blend4     0
# 9     Brazil  blend4     0
# 10  Columbia  blend6     0

# %%
df.sort_values(by=['Country'], inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#      Body   Acidity   Flavor   Aroma      Roast   Roastery   RoastDate  \
# 0   body1  acidity1  flavor2  aroma1      light  roastery2  2023-02-09
# 2   body2  acidity1  flavor5  aroma4   espresso  roastery3  2023-02-07
# 5   body3  acidity2  flavor4  aroma5       dark  roastery2  2023-02-03
# 1   body6  acidity6  flavor6  aroma6  unroasted  roastery6  2023-02-09
# 4   body4  acidity2  flavor3  aroma2     medium  roastery1  2023-02-04
# 6   body2  acidity4  flavor3  aroma4       dark  roastery3  2023-02-02
# 7   body1  acidity5  flavor2  aroma3      light  roastery1  2023-02-01
# 8   body2  acidity4  flavor2  aroma2      light  roastery3  2023-01-25
# 3   body3  acidity5  flavor4  aroma1     medium  roastery5  2023-02-07
# 9   body1  acidity3  flavor1  aroma1     medium  roastery5  2023-01-24
# 10  body5  acidity1  flavor5  aroma4     medium  roastery3  2023-01-23
#
#      Country   Blend  Sold
# 0     Brazil  blend2     0
# 2     Brazil  blend4     0
# 5     Brazil  blend4     0
# 1   Columbia  blend6     0
# 4   Columbia  blend3     0
# 6   Columbia  blend5     0
# 7   Columbia  blend1     0
# 8   Ethiopia  blend3     0
# 3   Honduras  blend2     0
# 9   Honduras  blend1     0
# 10   Vietnam  blend5     0

# %%
df.sort_values(by=['RoastDate'], inplace=True)
df.reset_index(drop=True, inplace=True)
df
# Out:
#      Body   Acidity   Flavor   Aroma      Roast   Roastery   RoastDate  \
# 0   body1  acidity1  flavor2  aroma1      light  roastery2  2023-02-09
# 1   body6  acidity6  flavor6  aroma6  unroasted  roastery6  2023-02-09
# 2   body2  acidity1  flavor5  aroma4   espresso  roastery3  2023-02-07
# 3   body3  acidity5  flavor4  aroma1     medium  roastery5  2023-02-07
# 4   body4  acidity2  flavor3  aroma2     medium  roastery1  2023-02-04
# 5   body3  acidity2  flavor4  aroma5       dark  roastery2  2023-02-03
# 6   body2  acidity4  flavor3  aroma4       dark  roastery3  2023-02-02
# 7   body1  acidity5  flavor2  aroma3      light  roastery1  2023-02-01
# 8   body2  acidity4  flavor2  aroma2      light  roastery3  2023-01-25
# 9   body1  acidity3  flavor1  aroma1     medium  roastery5  2023-01-24
# 10  body5  acidity1  flavor5  aroma4     medium  roastery3  2023-01-23
#
#      Country   Blend  Sold
# 0     Brazil  blend2     0
# 1   Columbia  blend6     0
# 2     Brazil  blend4     0
# 3   Honduras  blend2     0
# 4   Columbia  blend3     0
# 5     Brazil  blend4     0
# 6   Columbia  blend5     0
# 7   Columbia  blend1     0
# 8   Ethiopia  blend3     0
# 9   Honduras  blend1     0
# 10   Vietnam  blend5     0

# %%
df.loc[5]

# %%
df.loc[10]['Roast']

# %%
df.at[0, 'Sold'] = 3

# %%
df

# %%
klajfkaldjflsdjfljflasfkjsdafljsfdlj
